# %% [markdown]
# # Baseball Regression Modeling Managing Multicollinearity with PCA

# %% [markdown]
# ## Learning Objectives

# %% [markdown]
# Use Principal Components Decomposition/Analysis to model out multicollinearity
#     * identify multicollinearity in the covariates
#     * fit and interpret PCA
#     * run regression on principal components

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import statsmodels.api as sms
import sklearn.decomposition as dcmp

# %%
# %matplotlib inline

# %% [markdown]
# ## Get Data and Subset Data

# %%
# retrieve csv file and store to dataframe
df = pd.read_csv('baseball_data.csv')

# subset the dataframe removing rows with NULL values
bix = df.notnull().all(axis=1)
df = df[bix]

# %% [markdown]
# ## A First Regression Model Using All Variables

# %% [markdown]
# The hope here is that we can get a batch look at how the variables relate to the target. This unfortunately fails due to tight correlations within the covariates.

# %%
model = sms.OLS(df.salary_in_thousands_of_dollars, sms.add_constant(df.iloc[:, 1:]))

# %% [markdown]
# Notes:
#     * we acheive a fairly high R2 right off the bat with this approach
#     * a couple of variables are significant or nearly so
#         - on_base_percentage
#         - number_of_runs
#         - number_of_runs_batted_in
#         - number_of_strike_outs
#         - number_of_stolen_bases
#         - indicator_of_free_agency_eligibility
#         - indicator_of_free_agent_in_1991_1992
#         - indicator_of_arbitration_eligibility
#         - indicator_of_arbitration_in_1991_1992
#     * there are a large number of variables, how do we know what should be in the model and what should be out?
#     * warning 2 in the printed output below states there may be high multicollinearity (high correlation between covariates)

# %%
result = model.fit()

# %%
print(result.summary())
# Out:
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     salary_in_thousands_of_dollars   R-squared:                       0.711
# Model:                                        OLS   Adj. R-squared:                  0.696
# Method:                             Least Squares   F-statistic:                     47.90
# Date:                            Fri, 24 Mar 2017   Prob (F-statistic):           4.71e-74
# Time:                                    10:46:51   Log-Likelihood:                -2602.7
# No. Observations:                             329   AIC:                             5239.
# Df Residuals:                                 312   BIC:                             5304.
# Df Model:                                      16
# Covariance Type:                        nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# const                                   358.1683    328.898      1.089      0.277    -288.971    1005.307
# batting_average                        2888.8905   2791.277      1.035      0.301   -2603.216    8380.997
# on_base_percentage                    -3837.4642   2399.913     -1.599      0.111   -8559.525     884.596
# number_of_runs                            8.9410      5.541      1.614      0.108      -1.962      19.844
# number_of_hits                           -2.6934      3.291     -0.818      0.414      -9.168       3.782
# number_of_doubles                        -2.1494      8.467     -0.254      0.800     -18.810      14.511
# number_of_triples                       -22.7478     21.212     -1.072      0.284     -64.485      18.989
# number_of_home_runs                      12.7920     12.377      1.034      0.302     -11.561      37.145
# number_of_runs_batted_in                 19.2680      4.975      3.873      0.000       9.480      29.056
# number_of_walks                           5.6493      4.474      1.263      0.208      -3.154      14.453
# number_of_strike_outs                    -9.9699      2.106     -4.733      0.000     -14.114      -5.825
# number_of_stolen_bases                   12.4465      4.654      2.674      0.008       3.289      21.604
# number_of_errors                        -10.3114      7.380     -1.397      0.163     -24.832       4.209
# indicator_of_free_agency_eligibility   1401.9627    106.539     13.159      0.000    1192.337    1611.588
# indicator_of_free_agent_in_1991_1992   -389.6385    136.471     -2.855      0.005    -658.158    -121.119
# indicator_of_arbitration_eligibility    801.9127    116.551      6.880      0.000     572.588    1031.238
# indicator_of_arbitration_in_1991_1992   398.7514    247.671      1.610      0.108     -88.565     886.067
# ==============================================================================
# Omnibus:                       29.533   Durbin-Watson:                   1.591
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               61.562
# Skew:                           0.480   Prob(JB):                     4.29e-14
# Kurtosis:                       4.889   Cond. No.                     1.45e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.45e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Look at Correlations in the Covariates

# %% [markdown]
# We should look at correlations in the covariates.

# %% [markdown]
# Chaining .style.background_gradient(cmap='viridis') on the end of the corr() call, styles the correlation matrix help us find high correlation items.

# %% [markdown]
# Notes:
#     * there are high correlations between salary and a number of variables that are not significant in the first model
#     * there is low correlation between a number of the variables which appear significant and salary
#     * there is high correlation between some of the variables which are highly correlated with salary and which do not show up as significant
#     * these correlations between the covariates may be causing us issues

# %%
df.corr().style.background_gradient(cmap='Blues')
# Out:
#         <style  type="text/css" >
#
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow0_col0 {
#
#                 background-color:  #08306b;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow0_col1 {
#
#                 background-color:  #b3d3e8;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow0_col2 {
#
#                 background-color:  #a5cde3;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow0_col3 {
#
#                 background-color:  #3c8cc3;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow0_col4 {
#
#                 background-color:  #4695c8;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow0_col5 {
#
#                 background-color:  #519ccc;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow0_col6 {
#
#                 background-color:  #c9ddf0;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow0_col7 {
#
#                 background-color:  #4a98c9;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow0_col8 {
#
#                 background-color:  #3888c1;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow0_col9 {
#
#                 background-color:  #57a0ce;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow0_col10 {
#
#                 background-color:  #91c3de;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow0_col11 {
#
#                 background-color:  #b7d4ea;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow0_col12 {
#
#                 background-color:  #dceaf6;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow0_col13 {
#
#                 background-color:  #3282be;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow0_col14 {
#
#                 background-color:  #cadef0;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow0_col15 {
#
#                 background-color:  #9cc9e1;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow0_col16 {
#
#                 background-color:  #cddff1;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow1_col0 {
#
#                 background-color:  #cde0f1;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow1_col1 {
#
#                 background-color:  #08306b;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow1_col2 {
#
#                 background-color:  #135fa7;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow1_col3 {
#
#                 background-color:  #79b5d9;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow1_col4 {
#
#                 background-color:  #65aad4;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow1_col5 {
#
#                 background-color:  #72b2d8;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow1_col6 {
#
#                 background-color:  #bcd7eb;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow1_col7 {
#
#                 background-color:  #c4daee;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow1_col8 {
#
#                 background-color:  #9cc9e1;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow1_col9 {
#
#                 background-color:  #b9d6ea;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow1_col10 {
#
#                 background-color:  #e1edf8;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow1_col11 {
#
#                 background-color:  #c3daee;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow1_col12 {
#
#                 background-color:  #d4e4f4;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow1_col13 {
#
#                 background-color:  #add0e6;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow1_col14 {
#
#                 background-color:  #e0ecf8;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow1_col15 {
#
#                 background-color:  #a4cce3;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow1_col16 {
#
#                 background-color:  #d1e2f3;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow2_col0 {
#
#                 background-color:  #c4daee;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow2_col1 {
#
#                 background-color:  #135fa7;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow2_col2 {
#
#                 background-color:  #08306b;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow2_col3 {
#
#                 background-color:  #61a7d2;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow2_col4 {
#
#                 background-color:  #7fb9da;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow2_col5 {
#
#                 background-color:  #8abfdd;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow2_col6 {
#
#                 background-color:  #cee0f2;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow2_col7 {
#
#                 background-color:  #aacfe5;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow2_col8 {
#
#                 background-color:  #95c5df;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow2_col9 {
#
#                 background-color:  #4d99ca;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow2_col10 {
#
#                 background-color:  #caddf0;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow2_col11 {
#
#                 background-color:  #bcd7eb;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow2_col12 {
#
#                 background-color:  #deebf7;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow2_col13 {
#
#                 background-color:  #92c4de;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow2_col14 {
#
#                 background-color:  #e2edf8;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow2_col15 {
#
#                 background-color:  #b7d4ea;
#
#             }
#
#             #T_dced2ea4_10b9_11e7_8f20_000c29f7289erow2_col16 {
#
#                 background-color:  #d8e7f5;

# %% [markdown]
# ## Managing Correlations in Covariates

# %% [markdown]
# ###### Create and Fit a PCA Object

# %%
pca = dcmp.PCA()
pca.fit(df.iloc[:, 1:])
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %% [markdown]
# ###### Review the Components

# %% [markdown]
# If the model is meant to be interpreted and not just provide predictions, then we need to provide an interpretation of the variables.
#
# Below we review the PCs and see:
#     - the variables number_of_THIS where THIS is a thing that happens while batting are all heavily loaded in PC1
#     - number_of_hits and number_of_runs are loaded heavy positive and home_runs, rbis, walks, and strike_outs are loaded heavy negative for PC2
#
# Our interpretation for the first two PCs is as follows:
#     - PC1 describes number of at bats
#         * as noted above the variance explained here is all of the variety count of things while at bat
#     - PC2 describes at bat efficacy
#         * here the major loadings are positive number_of_hits and negative number_of_strike_outs (the loadings are "competing")

# %%
pd.DataFrame(pca.components_.T, 
                columns=['PC' + str(i+1) for i in range(pca.components_.shape[1])],
                index=df.iloc[:, 1:].columns)
# Out:
#                                             PC1       PC2       PC3       PC4  \
# batting_average                        0.000240 -0.000705 -0.000100 -0.000136
# on_base_percentage                     0.000307 -0.000355  0.001091 -0.000639
# number_of_runs                         0.380021 -0.118796  0.333337  0.059844
# number_of_hits                         0.688515 -0.491051 -0.239587  0.236612
# number_of_doubles                      0.126091 -0.072576 -0.093360 -0.044433
# number_of_triples                      0.017363 -0.021838  0.006945  0.070167
# number_of_home_runs                    0.095636  0.138186 -0.087914 -0.239165
# number_of_runs_batted_in               0.373059  0.121746 -0.330874 -0.633950
# number_of_walks                        0.279298  0.137899  0.780132 -0.338257
# number_of_strike_outs                  0.365514  0.824466 -0.144979  0.382308
# number_of_stolen_bases                 0.066122 -0.077024  0.272995  0.453855
# number_of_errors                       0.032044 -0.019855 -0.036642  0.088627
# indicator_of_free_agency_eligibility   0.002068  0.000003  0.003192 -0.004965
# indicator_of_free_agent_in_1991_1992   0.000020 -0.000743 -0.000605 -0.000736
# indicator_of_arbitration_eligibility   0.000785 -0.002514 -0.002685  0.001333
# indicator_of_arbitration_in_1991_1992  0.000242 -0.000567 -0.000881  0.000001
#
#                                             PC5       PC6       PC7       PC8  \
# batting_average                        0.000004  0.000033 -0.000323  0.000157
# on_base_percentage                    -0.000267 -0.000070 -0.000278 -0.000027
# number_of_runs                         0.439999  0.685179  0.117494  0.099056
# number_of_hits                        -0.324548 -0.130723 -0.105151  0.141678
# number_of_doubles                     -0.016194  0.152943 -0.117330 -0.962306
# number_of_triples                      0.038200  0.017602 -0.028820  0.054119
# number_of_home_runs                    0.228669  0.134292  0.001779  0.083625
# number_of_runs_batted_in               0.368845 -0.309106  0.089595  0.021620
# number_of_walks                       -0.345319 -0.227853 -0.017771 -0.057419
# number_of_strike_outs                 -0.112248  0.041896 -0.044566 -0.007106
# number_of_stolen_bases                 0.601896 -0.565060 -0.007792 -0.129349
# number_of_errors                      -0.129851 -0.056368  0.974622 -0.115204
# indicator_of_free_agency_eligibility  -0.003317 -0.001370 -0.011366  0.014782
# indicator_of_free_agent_in_1991_1992  -0.003827 -0.002656  0.004013  0.006540
# indicator_of_arbitration_eligibility   0.000883 -0.000114  0.010466 -0.008771
# indicator_of_arbitration_in_1991_1992 -0.000302  0.002889  0.002215 -0.001978
#
#                                             PC9      PC10      PC11      PC12  \
# batting_average                       -0.000761 -0.000042  0.005236 -0.012015
# on_base_percentage                    -0.000911 -0.000578  0.003954 -0.011137
# number_of_runs                         0.174795  0.097584 -0.002831  0.001074
# number_of_hits                        -0.133533 -0.002352  0.005752 -0.002332
# number_of_doubles                     -0.032877 -0.057615 -0.016959  0.000565
# number_of_triples                      0.267975 -0.957405 -0.016065 -0.004431
# number_of_home_runs                   -0.876007 -0.248686  0.009614  0.000445
# number_of_runs_batted_in               0.303717  0.047754 -0.002692 -0.001657
# number_of_walks                       -0.049467 -0.051837  0.006124 -0.000141
# number_of_strike_outs                  0.049146  0.025779 -0.000537  0.001813
# number_of_stolen_bases                -0.102683  0.016061 -0.003277  0.001332
# number_of_errors                      -0.057587 -0.050637 -0.014441 -0.007594
# indicator_of_free_agency_eligibility  -0.017462  0.008320 -0.783919  0.308418
# indicator_of_free_agent_in_1991_1992   0.006558  0.004530 -0.361002  0.478330
# indicator_of_arbitration_eligibility   0.003850 -0.011705  0.498285  0.811375
# indicator_of_arbitration_in_1991_1992  0.002335  0.001264  0.076644  0.131863
#
#                                            PC13      PC14      PC15      PC16
# batting_average                        0.006189  0.003322  0.645185 -0.763881
# on_base_percentage                     0.001859  0.007767  0.763763  0.645337
# number_of_runs                        -0.000732 -0.002296  0.000007 -0.000048
# number_of_hits                         0.002045  0.000414 -0.000678  0.000380
# number_of_doubles                      0.001310 -0.000819  0.000025 -0.000076
# number_of_triples                     -0.001386  0.002487 -0.000108 -0.000310
# number_of_home_runs                    0.013347  0.002020 -0.001262 -0.000024
# number_of_runs_batted_in              -0.003603  0.000027  0.000326  0.000064
# number_of_walks                        0.002102  0.001010 -0.001027 -0.000847
# number_of_strike_outs                 -0.000998 -0.000209  0.000859 -0.000043
# number_of_stolen_bases                 0.001121  0.002130 -0.000015 -0.000005
# number_of_errors                      -0.005937 -0.000284  0.000355 -0.000090
# indicator_of_free_agency_eligibility  -0.537927 -0.005341  0.012960 -0.003633
# indicator_of_free_agent_in_1991_1992   0.800434  0.001610  0.005753  0.001346
# indicator_of_arbitration_eligibility  -0.259853 -0.159187  0.012706 -0.001420
# indicator_of_arbitration_in_1991_1992 -0.046185  0.987185 -0.006066 -0.002756

# %% [markdown]
# ###### Review the Scree Plot

# %%
pd.Series(pca.explained_variance_ratio_).plot(title='Scree Plot');

# %% [markdown]
# ###### Get the Transformed Data

# %%
transformed = pca.fit_transform(df.iloc[:, 1:])
reduced = transformed[:, :2]
data = pd.DataFrame(reduced, columns=['p1', 'p2'])

# %% [markdown]
# ###### Fit Regression on the Transformed Data

# %%
model = sms.OLS(df.salary_in_thousands_of_dollars.reset_index().drop('index', axis=1), sms.add_constant(data))

# %%
results = model.fit()

# %%
print(results.summary())
# Out:
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     salary_in_thousands_of_dollars   R-squared:                       0.425
# Model:                                        OLS   Adj. R-squared:                  0.421
# Method:                             Least Squares   F-statistic:                     120.4
# Date:                            Fri, 24 Mar 2017   Prob (F-statistic):           6.90e-40
# Time:                                    10:46:52   Log-Likelihood:                -2715.8
# No. Observations:                             329   AIC:                             5438.
# Df Residuals:                                 326   BIC:                             5449.
# Df Model:                                       2
# Covariance Type:                        nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1248.3647     51.532     24.225      0.000    1146.988    1349.741
# p1            10.8503      0.710     15.279      0.000       9.453      12.247
# p2            -5.7921      2.127     -2.723      0.007      -9.976      -1.608
# ==============================================================================
# Omnibus:                       15.761   Durbin-Watson:                   1.168
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               18.630
# Skew:                           0.438   Prob(JB):                     9.00e-05
# Kurtosis:                       3.769   Cond. No.                         72.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
