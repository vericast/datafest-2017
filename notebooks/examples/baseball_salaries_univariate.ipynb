# %% [markdown]
# # Baseball Salaries Univariate Insights

# %% [markdown]
# ## Learning Objectives

# %% [markdown]
# Review information related to individual columns
#     * summary stats
#     * density plots
#     * slicing groups and comparing group distributions

# %%
import pandas as pd

# %%
# %matplotlib inline

# %% [markdown]
# ## Get Data

# %%
df = pd.read_csv('baseball_data.csv')

# %% [markdown]
# ## Salaries Summary Sats

# %% [markdown]
# Notes:
#     * Median Salary is 740,000
#     * Mean Salary is 1,250,000
#     * The distribution is highly skewed as will be shown in the KDE plot below.

# %%
df.salary_in_thousands_of_dollars.describe()
# Out:
# count     337.000000
# mean     1248.528190
# std      1240.013309
# min       109.000000
# 25%       230.000000
# 50%       740.000000
# 75%      2150.000000
# max      6100.000000
# Name: salary_in_thousands_of_dollars, dtype: float64

# %% [markdown]
# ## KDE Plot Salary

# %% [markdown]
# Notes:
#     * as expected we see a right skew
#     * this is reasonable since the values are forced to be greater than zero
#     * there may be some bimodality

# %%
df.salary_in_thousands_of_dollars.plot(kind='kde');

# %% [markdown]
# ## View Univariate Stats within Groups

# %% [markdown]
# ###### indicator_of_free_agency_eligibility

# %% [markdown]
# Notes:
#     * green is ineligible, blue is eligible
#     * eligble players appear to be paid significantly more when we look at median salaries

# %%
col = 'indicator_of_free_agency_eligibility'
grp = df.groupby(col).salary_in_thousands_of_dollars
print(grp.describe())

bix = df[col] == 1
df[bix].salary_in_thousands_of_dollars.plot(kind='kde');

df[~bix].salary_in_thousands_of_dollars.plot(kind='kde');
# Out:
# indicator_of_free_agency_eligibility
# 0.0                                   count     202.000000
#                                       mean      680.673267
#                                       std       855.376198
#                                       min       109.000000
#                                       25%       150.000000
#                                       50%       322.500000
#                                       75%       797.500000
#                                       max      5150.000000
# 1.0                                   count     134.000000
#                                       mean     2108.940299
#                                       std      1241.193948
#                                       min       109.000000
#                                       25%       998.750000
#                                       50%      2171.000000
#                                       75%      2887.500000
#                                       max      6100.000000
# Name: salary_in_thousands_of_dollars, dtype: float64

# %% [markdown]
# ###### indicator_of_arbitration_eligibility

# %% [markdown]
# Notes:
#     * again eligible players are paid significantly more

# %%
col = 'indicator_of_arbitration_eligibility'
grp = df.groupby(col).salary_in_thousands_of_dollars
print(grp.describe())

bix = df[col] == 1
df[bix].salary_in_thousands_of_dollars.plot(kind='kde');

df[~bix].salary_in_thousands_of_dollars.plot(kind='kde');
# Out:
# indicator_of_arbitration_eligibility
# 0.0                                   count     271.000000
#                                       mean     1176.095941
#                                       std      1275.714715
#                                       min       109.000000
#                                       25%       183.000000
#                                       50%       525.000000
#                                       75%      2167.000000
#                                       max      6100.000000
# 1.0                                   count      65.000000
#                                       mean     1567.569231
#                                       std      1030.525776
#                                       min       109.000000
#                                       25%       850.000000
#                                       50%      1262.000000
#                                       75%      2050.000000
#                                       max      5150.000000
# Name: salary_in_thousands_of_dollars, dtype: float64

# %% [markdown]
# ###### indicator_of_free_agent_in_1991_1992

# %%
col = 'indicator_of_free_agent_in_1991_1992'
grp = df.groupby(col).salary_in_thousands_of_dollars
print(grp.describe())

bix = df[col] == 1
df[bix].salary_in_thousands_of_dollars.plot(kind='kde');

df[~bix].salary_in_thousands_of_dollars.plot(kind='kde');
# Out:
# indicator_of_free_agent_in_1991_1992
# 0                                     count     298.000000
#                                       mean     1195.546980
#                                       std      1207.977532
#                                       min       109.000000
#                                       25%       200.000000
#                                       50%       673.500000
#                                       75%      2100.000000
#                                       max      5150.000000
# 1                                     count      39.000000
#                                       mean     1653.358974
#                                       std      1414.504609
#                                       min       109.000000
#                                       25%       600.000000
#                                       50%      1150.000000
#                                       75%      2362.500000
#                                       max      6100.000000
# Name: salary_in_thousands_of_dollars, dtype: float64

# %% [markdown]
# ###### indicator_of_arbitration_in_1991_1992

# %%
col = 'indicator_of_arbitration_in_1991_1992'
grp = df.groupby(col).salary_in_thousands_of_dollars
print(grp.describe())

bix = df[col] == 1
df[bix].salary_in_thousands_of_dollars.plot(kind='kde');

df[~bix].salary_in_thousands_of_dollars.plot(kind='kde');
# Out:
# indicator_of_arbitration_in_1991_1992
# 0.0                                    count     326.000000
#                                        mean     1228.481595
#                                        std      1224.887734
#                                        min       109.000000
#                                        25%       230.000000
#                                        50%       720.000000
#                                        75%      2137.500000
#                                        max      6100.000000
# 1.0                                    count       9.000000
#                                        mean     2056.666667
#                                        std      1641.738789
#                                        min       125.000000
#                                        25%       875.000000
#                                        50%      1600.000000
#                                        75%      3300.000000
#                                        max      5000.000000
# Name: salary_in_thousands_of_dollars, dtype: float64
